# %% [markdown]
# # Make some plots

# %%
import sys
import pandas as pd

sys.path.append("/home/iwsatlas1/jgreen/DHBW/magicdl")

import magic

geom = magic.Geometry()
cam = magic.Camera()

# %%
cam.plot_camera()

# %%
gamma_file = "/remote/lstdata01/jgreen/MAGIC_MC/DHBW-parquet/magic-gammas.parquet"
proton_file = "/remote/lstdata01/jgreen/MAGIC_MC/DHBW-parquet/magic-protons.parquet"

p = pd.read_parquet(proton_file)
g = pd.read_parquet(gamma_file)

# %%
gex = g.sample().iloc[0]
e = magic.Event(gex, "gamma")
e.plot(2, cleaned=True, title=True)
e.plot(2, timing=True, title=True)

# %%
ex = p.sample().iloc[0]
e = magic.Event(ex, "hadron")

# good one: 118115.55

# %%
ex = p[(p.run_number == 118115) & (p.event_number == 55)].iloc[0]
e = magic.Event(ex, "hadron")

# %%
e.plot(1, title=True)
e.plot(1, timing=True, title=True)
